# %% [markdown]
# <a href="https://colab.research.google.com/github/addadugurudurga2024-lang/Flyrank/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/flyrank-bih/flyrank-ml-internship-starter/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1.My lane as an ML task (type)
#
# I am treating this problem as a **Classification** task.
#
# The goal is to classify each webpage into one of two categories:
#
# - Needs Content Refresh
# - Does Not Need Content Refresh
#
# This is similar to other binary classification problems such as Spam vs Not Spam or Fraud vs Not Fraud. The model learns patterns from historical data and predicts whether a webpage should be refreshed.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Task Type : Classification")
# Out:
# Task Type : Classification

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*
#
#
# The target column is **Needs_Refresh**.
#
# Possible values:
#
# - 1 → Needs Refresh
# - 0 → Does Not Need Refresh
#
# This target can be created from historical observations or business rules. For example, if a page's CTR decreases significantly while impressions remain high, it may be labeled as needing a refresh.

# %%
import pandas as pd
df = pd.DataFrame({'col1': range(10)}) # Create a dummy DataFrame with 10 rows
df["Needs_Refresh"] = [1 if i % 2 == 0 else 0 for i in range(len(df))]
df[["Needs_Refresh"]].head()
# Out:
#    Needs_Refresh
# 0              1
# 1              0
# 2              1
# 3              0
# 4              1

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*
#
# I will use **Accuracy** as the primary evaluation metric.
#
# Accuracy measures the percentage of webpages that are correctly classified as either needing a refresh or not needing a refresh.
#
# A higher accuracy indicates better overall performance. If the classes later become imbalanced, metrics such as Precision, Recall, or F1-score may also be considered.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Evaluation Metric : Accuracy")
# Out:
# Evaluation Metric : Accuracy

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# One row in this dataset represents **one webpage**.
#
# Each row contains measurements such as impressions, clicks, CTR, and other content-related information for that webpage.
#
# The model uses these features to decide whether the webpage needs to be refreshed.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd
df = pd.DataFrame({'col1': range(10), 'col2': ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J']}) # Create a dummy DataFrame

print(df.head())

print("\nShape:", df.shape)
# Out:
#    col1 col2
# 0     0    A
# 1     1    B
# 2     2    C
# 3     3    D
# 4     4    E
#
# Shape: (10, 2)

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*
# A fixed rule such as:
#
# "If CTR < 0.20 then refresh the page"
#
# is too simple.
#
# The decision depends on many factors such as CTR, impressions, clicks, traffic trends, and other signals that interact with each other.
#
# Machine Learning can learn these complex relationships from historical data and make better predictions than a single hand-written rule.
#
# The output helps the content team decide which webpages should be refreshed first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("ML can learn complex patterns that fixed rules cannot.")
# Out:
# ML can learn complex patterns that fixed rules cannot.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - ✅Every section above is filled — markdown thinking AND the code that backs it
# -  ✅ The notebook runs top to bottom with no errors (Runtime → Run all)
# - ✅No client names, URLs, or private queries anywhere
# - ✅ My claims use careful words: observed, measured, directional, decision-support
# - ✅Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
